# %%
# !pip install catboost==0.15.2
# !pip install tqdm
# !pip install xlrd
import numpy as np
import pandas as pd
import catboost as cbt
from sklearn.metrics import accuracy_score, roc_auc_score,log_loss
import gc
import math
import time
from tqdm import tqdm
import datetime
from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from datetime import datetime,timedelta
import warnings
import os
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
train = pd.read_csv('.\\data\\first_round_training_data.csv')
test = pd.read_csv('.\\data\\first_round_testing_data.csv')
submit = pd.read_csv('.\\data\\submit_example.csv')
data = train.append(test).reset_index(drop=True)
dit = {'Excellent':0,'Good':1,'Pass':2,'Fail':3}
data['label'] = data['Quality_label'].map(dit)
train['label'] = train['Quality_label'].map(dit)

# %%
feature_name = ['Parameter{0}'.format(i) for i in range(5, 11)]
tr_index = ~data['label'].isnull()
X_train = data[tr_index][feature_name].reset_index(drop=True)
y = data[tr_index]['label'].reset_index(drop=True).astype(int)
X_test = data[~tr_index][feature_name].reset_index(drop=True)

print(X_train.shape,X_test.shape)
oof = np.zeros((X_train.shape[0],4))
prediction = np.zeros((X_test.shape[0],4))
seeds = [1, 2, 3, 4, 5, 6]
num_model_seed = 6
for model_seed in range(num_model_seed):
    print("out loop", model_seed + 1)
    oof_cat = np.zeros((X_train.shape[0],4))
    prediction_cat=np.zeros((X_test.shape[0],4))
    skf = StratifiedKFold(n_splits=5, random_state=seeds[model_seed], shuffle=True)
    for index, (train_index, test_index) in enumerate(skf.split(X_train, y)):
        print("inner loop", index)
        train_x, test_x, train_y, test_y = X_train.iloc[train_index], X_train.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        gc.collect()
        cbt_model = cbt.CatBoostClassifier(iterations=800,learning_rate=0.01,verbose=300,
                                        early_stopping_rounds=200,task_type='GPU',
                                        loss_function='MultiClass')
        cbt_model.fit(train_x, train_y ,eval_set=(train_x, train_y))
        oof_cat[test_index] += cbt_model.predict_proba(test_x)
        prediction_cat += cbt_model.predict_proba(X_test)/5
        gc.collect()
    oof += oof_cat / num_model_seed
    prediction += prediction_cat / num_model_seed
    print('logloss',log_loss(pd.get_dummies(y).values, oof_cat))
    print('ac',accuracy_score(y, np.argmax(oof_cat,axis=1)))
    print('mae',1/(1 + np.sum(np.absolute(np.eye(4)[y] - oof_cat))/480))
print('logloss',log_loss(pd.get_dummies(y).values, oof))
print('ac',accuracy_score(y, np.argmax(oof,axis=1)))
print('mae',1/(1 + np.sum(np.absolute(np.eye(4)[y] - oof))/480))
# Out:
# (6000, 6) (6000, 6)
# 1
# 0
# 0:	learn: 1.3808194	test: 1.3808195	best: 1.3808195 (0)	total: 121ms	remaining: 1m 36s
# 300:	learn: 1.0816335	test: 1.0816335	best: 1.0816335 (300)	total: 4.68s	remaining: 7.76s
# 600:	learn: 1.0476845	test: 1.0476845	best: 1.0476845 (600)	total: 9.12s	remaining: 3.02s
# 799:	learn: 1.0319359	test: 1.0319359	best: 1.0319359 (799)	total: 12s	remaining: 0us
# bestTest = 1.031935914
# bestIteration = 799
# Shrink model to first 800 iterations.
# 1
# 0:	learn: 1.3808341	test: 1.3808342	best: 1.3808342 (0)	total: 18.1ms	remaining: 14.5s
# 300:	learn: 1.0844650	test: 1.0844651	best: 1.0844651 (300)	total: 4.53s	remaining: 7.5s
# 600:	learn: 1.0514472	test: 1.0514471	best: 1.0514471 (600)	total: 8.88s	remaining: 2.94s
# 799:	learn: 1.0361601	test: 1.0361601	best: 1.0361601 (799)	total: 11.8s	remaining: 0us
# bestTest = 1.036160086
# bestIteration = 799
# Shrink model to first 800 iterations.
# 2
# 0:	learn: 1.3812906	test: 1.3812906	best: 1.3812906 (0)	total: 16.5ms	remaining: 13.2s
# 300:	learn: 1.0838066	test: 1.0838064	best: 1.0838064 (300)	total: 4.48s	remaining: 7.43s
# 600:	learn: 1.0486913	test: 1.0486913	best: 1.0486913 (600)	total: 8.9s	remaining: 2.95s
# 799:	learn: 1.0338212	test: 1.0338213	best: 1.0338213 (799)	total: 11.9s	remaining: 0us
# bestTest = 1.033821282
# bestIteration = 799
# Shrink model to first 800 iterations.
# 3
# 0:	learn: 1.3808998	test: 1.3808996	best: 1.3808996 (0)	total: 17.2ms	remaining: 13.7s
# 300:	learn: 1.0837815	test: 1.0837816	best: 1.0837816 (300)	total: 4.46s	remaining: 7.4s
# 600:	learn: 1.0535539	test: 1.0535540	best: 1.0535540 (600)	total: 8.79s	remaining: 2.91s
# 799:	learn: 1.0387309	test: 1.0387309	best: 1.0387309 (799)	total: 11.7s	remaining: 0us
# bestTest = 1.038730945
# bestIteration = 799
# Shrink model to first 800 iterations.
# 4
# 0:	learn: 1.3809294	test: 1.3809293	best: 1.3809293 (0)	total: 17.5ms	remaining: 14s
# 300:	learn: 1.0900870	test: 1.0900870	best: 1.0900870 (300)	total: 4.5s	remaining: 7.45s
# 600:	learn: 1.0592107	test: 1.0592107	best: 1.0592107 (600)	total: 8.84s	remaining: 2.93s
# 799:	learn: 1.0450511	test: 1.0450511	best: 1.0450511 (799)	total: 11.8s	remaining: 0us
# bestTest = 1.045051114
# bestIteration = 799
# Shrink model to first 800 iterations.
# logloss 1.0935989589712243
# ac 0.5286666666666666
# mae 0.06250334911674282
# 2
# 0
# 0:	learn: 1.3808109	test: 1.3808107	best: 1.3808107 (0)	total: 19.4ms	remaining: 15.5s
# 300:	learn: 1.0836129	test: 1.0836128	best: 1.0836128 (300)	total: 4.47s	remaining: 7.42s
# 600:	learn: 1.0518838	test: 1.0518837	best: 1.0518837 (600)	total: 8.78s	remaining: 2.91s
# 799:	learn: 1.0375633	test: 1.0375632	best: 1.0375632 (799)	total: 11.7s	remaining: 0us
# bestTest = 1.037563157
# bestIteration = 799
# Shrink model to first 800 iterations.
# 1
# 0:	learn: 1.3807919	test: 1.3807920	best: 1.3807920 (0)	total: 19.4ms	remaining: 15.5s
# 300:	learn: 1.0812290	test: 1.0812290	best: 1.0812290 (300)	total: 4.51s	remaining: 7.47s
# 600:	learn: 1.0483905	test: 1.0483906	best: 1.0483906 (600)	total: 8.84s	remaining: 2.93s
# 799:	learn: 1.0334231	test: 1.0334232	best: 1.0334232 (799)	total: 11.8s	remaining: 0us
# bestTest = 1.033423248
# bestIteration = 799
# Shrink model to first 800 iterations.
# 2
# 0:	learn: 1.3809351	test: 1.3809351	best: 1.3809351 (0)	total: 16.7ms	remaining: 13.3s
# 300:	learn: 1.0860833	test: 1.0860833	best: 1.0860833 (300)	total: 4.41s	remaining: 7.31s
# 600:	learn: 1.0540120	test: 1.0540119	best: 1.0540119 (600)	total: 8.99s	remaining: 2.98s
# 799:	learn: 1.0382678	test: 1.0382679	best: 1.0382679 (799)	total: 11.9s	remaining: 0us
# bestTest = 1.038267886
# bestIteration = 799
# Shrink model to first 800 iterations.
# 3
# 0:	learn: 1.3808576	test: 1.3808577	best: 1.3808577 (0)	total: 18.2ms	remaining: 14.6s
# 300:	learn: 1.0852105	test: 1.0852104	best: 1.0852104 (300)	total: 4.47s	remaining: 7.41s
# 600:	learn: 1.0515408	test: 1.0515408	best: 1.0515408 (600)	total: 8.82s	remaining: 2.92s
# 799:	learn: 1.0366453	test: 1.0366453	best: 1.0366453 (799)	total: 11.8s	remaining: 0us
# bestTest = 1.036645299
# bestIteration = 799
# Shrink model to first 800 iterations.
# 4
# 0:	learn: 1.3809061	test: 1.3809061	best: 1.3809061 (0)	total: 16.5ms	remaining: 13.1s
# 300:	learn: 1.0860689	test: 1.0860690	best: 1.0860690 (300)	total: 4.49s	remaining: 7.44s
# 600:	learn: 1.0548101	test: 1.0548100	best: 1.0548100 (600)	total: 8.82s	remaining: 2.92s
# 799:	learn: 1.0401862	test: 1.0401861	best: 1.0401861 (799)	total: 11.8s	remaining: 0us
# bestTest = 1.040186096
# bestIteration = 799
# Shrink model to first 800 iterations.
# logloss 1.092039173240877
# ac 0.5313333333333333
# mae 0.06254109612722696
# 3
# 0
# 0:	learn: 1.3807694	test: 1.3807695	best: 1.3807695 (0)	total: 51.5ms	remaining: 41.2s
# 300:	learn: 1.0806428	test: 1.0806429	best: 1.0806429 (300)	total: 4.57s	remaining: 7.58s
# 600:	learn: 1.0456901	test: 1.0456898	best: 1.0456898 (600)	total: 9.03s	remaining: 2.99s
# 799:	learn: 1.0299549	test: 1.0299549	best: 1.0299549 (799)	total: 12s	remaining: 0us
# bestTest = 1.029954905
# bestIteration = 799
# Shrink model to first 800 iterations.
# 1
# 0:	learn: 1.3809133	test: 1.3809134	best: 1.3809134 (0)	total: 20.3ms	remaining: 16.2s
# 300:	learn: 1.0888977	test: 1.0888977	best: 1.0888977 (300)	total: 4.5s	remaining: 7.45s
# 600:	learn: 1.0564487	test: 1.0564487	best: 1.0564487 (600)	total: 9.06s	remaining: 3s
# 799:	learn: 1.0416071	test: 1.0416071	best: 1.0416071 (799)	total: 12s	remaining: 0us
# bestTest = 1.041607099
# bestIteration = 799
# Shrink model to first 800 iterations.
# 2
# 0:	learn: 1.3808295	test: 1.3808294	best: 1.3808294 (0)	total: 19.4ms	remaining: 15.5s
# 300:	learn: 1.0834512	test: 1.0834511	best: 1.0834511 (300)	total: 4.55s	remaining: 7.54s
# 600:	learn: 1.0504949	test: 1.0504947	best: 1.0504947 (600)	total: 9.06s	remaining: 3s
# 799:	learn: 1.0356600	test: 1.0356601	best: 1.0356601 (799)	total: 12s	remaining: 0us
# bestTest = 1.035660092
# bestIteration = 799
# Shrink model to first 800 iterations.
# 3
# 0:	learn: 1.3808655	test: 1.3808655	best: 1.3808655 (0)	total: 19.5ms	remaining: 15.6s
# 300:	learn: 1.0853288	test: 1.0853289	best: 1.0853289 (300)	total: 4.55s	remaining: 7.54s
# 600:	learn: 1.0526736	test: 1.0526737	best: 1.0526737 (600)	total: 8.98s	remaining: 2.98s
# 799:	learn: 1.0375525	test: 1.0375524	best: 1.0375524 (799)	total: 12s	remaining: 0us
# bestTest = 1.037552398
# bestIteration = 799
# Shrink model to first 800 iterations.
# 4
# 0:	learn: 1.3809349	test: 1.3809350	best: 1.3809350 (0)	total: 17.2ms	remaining: 13.7s
# 300:	learn: 1.0861595	test: 1.0861595	best: 1.0861595 (300)	total: 4.48s	remaining: 7.43s
# 600:	learn: 1.0546392	test: 1.0546392	best: 1.0546392 (600)	total: 8.96s	remaining: 2.97s
# 799:	learn: 1.0397034	test: 1.0397035	best: 1.0397035 (799)	total: 12.2s	remaining: 0us
# bestTest = 1.039703509
# bestIteration = 799
# Shrink model to first 800 iterations.
# logloss 1.0942140000097837
# ac 0.5321666666666667
# mae 0.0625109810483688
# 4
# 0
# 0:	learn: 1.3808287	test: 1.3808287	best: 1.3808287 (0)	total: 18.6ms	remaining: 14.8s
# 300:	learn: 1.0788998	test: 1.0788999	best: 1.0788999 (300)	total: 4.52s	remaining: 7.49s
# 600:	learn: 1.0462409	test: 1.0462409	best: 1.0462409 (600)	total: 9s	remaining: 2.98s
# 799:	learn: 1.0298852	test: 1.0298852	best: 1.0298852 (799)	total: 11.9s	remaining: 0us
# bestTest = 1.029885194
# bestIteration = 799
# Shrink model to first 800 iterations.
# 1
# 0:	learn: 1.3811969	test: 1.3811970	best: 1.3811970 (0)	total: 16.7ms	remaining: 13.4s
# 300:	learn: 1.0874903	test: 1.0874903	best: 1.0874903 (300)	total: 4.72s	remaining: 7.83s
# 600:	learn: 1.0558490	test: 1.0558489	best: 1.0558489 (600)	total: 9.22s	remaining: 3.05s
# 799:	learn: 1.0413279	test: 1.0413281	best: 1.0413281 (799)	total: 12.2s	remaining: 0us
# bestTest = 1.041328052
# bestIteration = 799
# Shrink model to first 800 iterations.
# 2
# 0:	learn: 1.3809569	test: 1.3809570	best: 1.3809570 (0)	total: 16.4ms	remaining: 13.1s
# 300:	learn: 1.0862639	test: 1.0862640	best: 1.0862640 (300)	total: 4.5s	remaining: 7.46s
# 600:	learn: 1.0535709	test: 1.0535707	best: 1.0535707 (600)	total: 9.02s	remaining: 2.99s
# 799:	learn: 1.0390989	test: 1.0390989	best: 1.0390989 (799)	total: 12s	remaining: 0us
# bestTest = 1.03909891
# bestIteration = 799
# Shrink model to first 800 iterations.
# 3
# 0:	learn: 1.3808540	test: 1.3808539	best: 1.3808539 (0)	total: 18.6ms	remaining: 14.9s
# 300:	learn: 1.0862226	test: 1.0862227	best: 1.0862227 (300)	total: 4.5s	remaining: 7.46s
# 600:	learn: 1.0543923	test: 1.0543922	best: 1.0543922 (600)	total: 9.01s	remaining: 2.98s
# 799:	learn: 1.0403101	test: 1.0403100	best: 1.0403100 (799)	total: 12.1s	remaining: 0us
# bestTest = 1.040310002
# bestIteration = 799
# Shrink model to first 800 iterations.
# 4
# 0:	learn: 1.3809007	test: 1.3809007	best: 1.3809007 (0)	total: 19.1ms	remaining: 15.3s
# 300:	learn: 1.0863704	test: 1.0863706	best: 1.0863706 (300)	total: 4.53s	remaining: 7.51s
# 600:	learn: 1.0531741	test: 1.0531740	best: 1.0531740 (600)	total: 8.89s	remaining: 2.94s
# 799:	learn: 1.0381298	test: 1.0381298	best: 1.0381298 (799)	total: 11.9s	remaining: 0us
# bestTest = 1.038129763
# bestIteration = 799
# Shrink model to first 800 iterations.
# logloss 1.0912062207561388
# ac 0.5333333333333333
# mae 0.06258054507206764
# 5
# 0
# 0:	learn: 1.3807161	test: 1.3807160	best: 1.3807160 (0)	total: 18.3ms	remaining: 14.7s
# 300:	learn: 1.0785417	test: 1.0785417	best: 1.0785417 (300)	total: 4.42s	remaining: 7.33s
# 600:	learn: 1.0453227	test: 1.0453227	best: 1.0453227 (600)	total: 8.78s	remaining: 2.9s
# 799:	learn: 1.0302381	test: 1.0302383	best: 1.0302383 (799)	total: 11.7s	remaining: 0us
# bestTest = 1.030238328
# bestIteration = 799
# Shrink model to first 800 iterations.
# 1
# 0:	learn: 1.3810027	test: 1.3810026	best: 1.3810026 (0)	total: 17.2ms	remaining: 13.7s
# 300:	learn: 1.0909796	test: 1.0909797	best: 1.0909797 (300)	total: 4.53s	remaining: 7.51s
# 600:	learn: 1.0576571	test: 1.0576573	best: 1.0576573 (600)	total: 9.14s	remaining: 3.02s
# 799:	learn: 1.0423387	test: 1.0423386	best: 1.0423386 (799)	total: 12.1s	remaining: 0us
# bestTest = 1.042338605
# bestIteration = 799
# Shrink model to first 800 iterations.
# 2
# 0:	learn: 1.3814324	test: 1.3814325	best: 1.3814325 (0)	total: 18.7ms	remaining: 15s
# 300:	learn: 1.0923171	test: 1.0923170	best: 1.0923170 (300)	total: 4.58s	remaining: 7.58s
# 600:	learn: 1.0597794	test: 1.0597795	best: 1.0597795 (600)	total: 9.05s	remaining: 3s
# 799:	learn: 1.0449055	test: 1.0449057	best: 1.0449057 (799)	total: 12.2s	remaining: 0us
# bestTest = 1.044905704
# bestIteration = 799
# Shrink model to first 800 iterations.
# 3
# 0:	learn: 1.3808715	test: 1.3808717	best: 1.3808717 (0)	total: 22.1ms	remaining: 17.6s
# 300:	learn: 1.0847587	test: 1.0847587	best: 1.0847587 (300)	total: 4.39s	remaining: 7.27s
# 600:	learn: 1.0531832	test: 1.0531833	best: 1.0531833 (600)	total: 11s	remaining: 3.63s
# 799:	learn: 1.0385115	test: 1.0385115	best: 1.0385115 (799)	total: 15.4s	remaining: 0us
# bestTest = 1.038511467
# bestIteration = 799
# Shrink model to first 800 iterations.
# 4
# 0:	learn: 1.3807187	test: 1.3807188	best: 1.3807188 (0)	total: 55.4ms	remaining: 44.3s
# 300:	learn: 1.0748645	test: 1.0748644	best: 1.0748644 (300)	total: 7.32s	remaining: 12.1s
# 600:	learn: 1.0428020	test: 1.0428018	best: 1.0428018 (600)	total: 14.1s	remaining: 4.66s
# 799:	learn: 1.0284645	test: 1.0284643	best: 1.0284643 (799)	total: 18.7s	remaining: 0us
# bestTest = 1.028464295
# bestIteration = 799
# Shrink model to first 800 iterations.
# logloss 1.094054785888809
# ac 0.5275
# mae 0.06248063735229346
# 6
# 0
# 0:	learn: 1.3808030	test: 1.3808030	best: 1.3808030 (0)	total: 28.3ms	remaining: 22.6s
# 300:	learn: 1.0808302	test: 1.0808302	best: 1.0808302 (300)	total: 7.37s	remaining: 12.2s
# 600:	learn: 1.0481096	test: 1.0481096	best: 1.0481096 (600)	total: 14.1s	remaining: 4.67s
# 799:	learn: 1.0330560	test: 1.0330561	best: 1.0330561 (799)	total: 18.6s	remaining: 0us
# bestTest = 1.033056071
# bestIteration = 799
# Shrink model to first 800 iterations.
# 1
# 0:	learn: 1.3808229	test: 1.3808229	best: 1.3808229 (0)	total: 20.9ms	remaining: 16.7s
# 300:	learn: 1.0860252	test: 1.0860254	best: 1.0860254 (300)	total: 7.33s	remaining: 12.1s
# 600:	learn: 1.0553339	test: 1.0553339	best: 1.0553339 (600)	total: 14.4s	remaining: 4.76s
# 799:	learn: 1.0400021	test: 1.0400020	best: 1.0400020 (799)	total: 18.8s	remaining: 0us
# bestTest = 1.040002019
# bestIteration = 799
# Shrink model to first 800 iterations.
# 2
# 0:	learn: 1.3808066	test: 1.3808065	best: 1.3808065 (0)	total: 28.2ms	remaining: 22.5s
# 300:	learn: 1.0811056	test: 1.0811055	best: 1.0811055 (300)	total: 7.13s	remaining: 11.8s
# 600:	learn: 1.0479872	test: 1.0479871	best: 1.0479871 (600)	total: 14.2s	remaining: 4.71s
# 799:	learn: 1.0323686	test: 1.0323685	best: 1.0323685 (799)	total: 18.6s	remaining: 0us
# bestTest = 1.032368541
# bestIteration = 799
# Shrink model to first 800 iterations.
# 3
# 0:	learn: 1.3810091	test: 1.3810092	best: 1.3810092 (0)	total: 28.2ms	remaining: 22.5s
# 300:	learn: 1.0902493	test: 1.0902494	best: 1.0902494 (300)	total: 7.16s	remaining: 11.9s
# 600:	learn: 1.0571166	test: 1.0571167	best: 1.0571167 (600)	total: 13.8s	remaining: 4.57s
# 799:	learn: 1.0411706	test: 1.0411706	best: 1.0411706 (799)	total: 18.2s	remaining: 0us
# bestTest = 1.041170622
# bestIteration = 799
# Shrink model to first 800 iterations.
# 4
# 0:	learn: 1.3809033	test: 1.3809033	best: 1.3809033 (0)	total: 23.4ms	remaining: 18.7s
# 300:	learn: 1.0850907	test: 1.0850906	best: 1.0850906 (300)	total: 7.16s	remaining: 11.9s
# 600:	learn: 1.0529386	test: 1.0529386	best: 1.0529386 (600)	total: 14.3s	remaining: 4.73s
# 799:	learn: 1.0377874	test: 1.0377873	best: 1.0377873 (799)	total: 18.9s	remaining: 0us
# bestTest = 1.037787295
# bestIteration = 799
# Shrink model to first 800 iterations.
# logloss 1.0906660241986939
# ac 0.5311666666666667
# mae 0.06260566078142167
# logloss 1.0905684842535555
# ac 0.5348333333333334
# mae 0.06253701397297737

# %%
sub = test[['Group']]
prob_cols = [i for i in submit.columns if i not in ['Group']]
for i, f in enumerate(prob_cols):
    sub[f] = prediction[:, i]
for i in prob_cols:
    sub[i] = sub.groupby('Group')[i].transform('mean')
sub = sub.drop_duplicates()
sub.to_csv("submission.csv",index=False)
