# %%
from __future__ import print_function # 使python2.7能兼容print()函数
import numpy as np
import argparse
import cv2

# %%
image = cv2.imread("Koala.jpg")

# %%
# height: # of rows; width: # of columns
image.shape  # 维度依次为：height, width, channels，而像素尺寸表示为width * height
# Out:
# (768, 1024, 3)

# %%
cv2.imshow("Koala", image)
cv2.waitKey(0) # pause the execution until we press a key on our keyboard
# Out:
# -1

# %%
cv2.imwrite("Koala_1.png", image)
# Out:
# True

# %% [markdown]
# ______________

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# image = mpimg.imread("Koala.jpg")
# image = plt.imread("Koala.jpg")
image = cv2.imread("Koala.jpg")
plt.axis("off")  # 取消numbered axes
plt.imshow(image)
plt.show()

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
(b, g, r) = image[0, 0]
print(b, g, r)
# Out:
# 58 90 101

# %%
image[0, 0] = (0, 0, 255)
print(image[0, 0])
# Out:
# [  0   0 255]

# %%
corner = image[0:100, 0:100]
cv2.imshow("corner", corner)
cv2.waitKey(0)
# Out:
# -1

# %%
image[0:100, 0:100] = (0, 255, 0)
cv2.imshow('Updated', image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ____________

# %%
canvas = np.zeros((300, 300, 3), dtype='uint8')
cv2.imshow("canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
green = (0, 255, 0)
cv2.line(canvas, (0, 150), (300, 300), green)
cv2.imshow("canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
red = (0, 0, 255)
cv2.line(canvas, (300, 0), (0, 300), red, 3)
cv2.imshow("canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.rectangle(canvas, (10, 10), (60, 60), green)
cv2.imshow("canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.rectangle(canvas, (50, 200), (200, 225), red, 5)
cv2.imshow("canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
blue = (255, 0, 0)
cv2.rectangle(canvas, (200, 50), (225, 125), blue, -1)
cv2.imshow("canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
canvas = np.zeros((300, 300, 3), dtype='uint8')
# (centerX, centerY) = (canvas.shape[1]//2, canvas.shape[0]//3)
(centerX, centerY) = (0, 150)
white = (255, 255, 255)
cv2.circle(canvas, (centerX, centerY), 100, white, -1)
cv2.imshow("canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.circle?
