# %% [markdown]
# ## Extract CSV Files

# %%
import pickle
import csv

# %%
def csv2dicts(csvfile):
    data = []
    keys = []
    for row_index, row in enumerate(csvfile):
        if row_index == 0:
            keys = row
            print(row)
            continue
        # if row_index % 10000 == 0:
        #     print(row_index)
        data.append({key: value for key, value in zip(keys, row)})
    return data


def set_nan_as_string(data, replace_str='0'):
    for i, x in enumerate(data):
        for key, value in x.items():
            if value == '':
                x[key] = replace_str
        data[i] = x

# %%
train_data = "E:\\DL_datasets\\Rossmann\\train.csv"
store_data = "E:\\DL_datasets\\Rossmann\\store.csv"
store_states = 'E:\\DL_datasets\\Rossmann\\store_states.csv'

# %%
with open(train_data) as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    with open('E:\\DL_datasets\\Rossmann\\train_data.pickle', 'wb') as f:
        data = csv2dicts(data)
        data = data[::-1] # 翻转list
        pickle.dump(data, f, -1)
        print(data[:3])
# Out:
# ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday']
# [{'Store': '1115', 'DayOfWeek': '2', 'Date': '2013-01-01', 'Sales': '0', 'Customers': '0', 'Open': '0', 'Promo': '0', 'StateHoliday': 'a', 'SchoolHoliday': '1'}, {'Store': '1114', 'DayOfWeek': '2', 'Date': '2013-01-01', 'Sales': '0', 'Customers': '0', 'Open': '0', 'Promo': '0', 'StateHoliday': 'a', 'SchoolHoliday': '1'}, {'Store': '1113', 'DayOfWeek': '2', 'Date': '2013-01-01', 'Sales': '0', 'Customers': '0', 'Open': '0', 'Promo': '0', 'StateHoliday': 'a', 'SchoolHoliday': '1'}]

# %%
pickle.dump?

# %%
with open(store_data) as csvfile, open(store_states) as csvfile2:
    data = csv.reader(csvfile, delimiter=',')
    state_data = csv.reader(csvfile2, delimiter=',')
    with open('E:\\DL_datasets\\Rossmann\\store_data.pickle', 'wb') as f:
        data = csv2dicts(data)
        state_data = csv2dicts(state_data)
        set_nan_as_string(data)  # 补充缺失值为0
        for index, val in enumerate(data):
            state = state_data[index]
            val['State'] = state['State']
            data[index] = val
        pickle.dump(data, f, -1)
        print(data[:2])
# Out:
# ['Store', 'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']
# ['Store', 'State']
# [{'Store': '1', 'StoreType': 'c', 'Assortment': 'a', 'CompetitionDistance': '1270', 'CompetitionOpenSinceMonth': '9', 'CompetitionOpenSinceYear': '2008', 'Promo2': '0', 'Promo2SinceWeek': '0', 'Promo2SinceYear': '0', 'PromoInterval': '0', 'State': 'HE'}, {'Store': '2', 'StoreType': 'a', 'Assortment': 'a', 'CompetitionDistance': '570', 'CompetitionOpenSinceMonth': '11', 'CompetitionOpenSinceYear': '2007', 'Promo2': '1', 'Promo2SinceWeek': '13', 'Promo2SinceYear': '2010', 'PromoInterval': 'Jan,Apr,Jul,Oct', 'State': 'TH'}]

# %%
with open(store_data) as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    with open('E:\\DL_datasets\\Rossmann\\store_data.pickle', 'wb') as f:
        data = csv2dicts(data)
        set_nan_as_string(data)
        pickle.dump(data, f, -1)
        print(data[:3])
# Out:
# ['Store', 'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']
# [{'Store': '1', 'StoreType': 'c', 'Assortment': 'a', 'CompetitionDistance': '1270', 'CompetitionOpenSinceMonth': '9', 'CompetitionOpenSinceYear': '2008', 'Promo2': '0', 'Promo2SinceWeek': '0', 'Promo2SinceYear': '0', 'PromoInterval': '0'}, {'Store': '2', 'StoreType': 'a', 'Assortment': 'a', 'CompetitionDistance': '570', 'CompetitionOpenSinceMonth': '11', 'CompetitionOpenSinceYear': '2007', 'Promo2': '1', 'Promo2SinceWeek': '13', 'Promo2SinceYear': '2010', 'PromoInterval': 'Jan,Apr,Jul,Oct'}, {'Store': '3', 'StoreType': 'a', 'Assortment': 'a', 'CompetitionDistance': '14130', 'CompetitionOpenSinceMonth': '12', 'CompetitionOpenSinceYear': '2006', 'Promo2': '1', 'Promo2SinceWeek': '14', 'Promo2SinceYear': '2011', 'PromoInterval': 'Jan,Apr,Jul,Oct'}]

# %% [markdown]
# ## Prepare Features

# %%
import pickle
from datetime import datetime
from sklearn import preprocessing
import numpy as np
import random
random.seed(923)

# %%
with open('E:\\DL_datasets\\Rossmann\\train_data.pickle', 'rb') as f:
    train_data = pickle.load(f)
    num_records = len(train_data)
with open('E:\\DL_datasets\\Rossmann\\store_data.pickle', 'rb') as f:
    store_data = pickle.load(f)
print(num_records)
# Out:
# 1017209

# %%
train_data[:2]
# Out:
# [{'Store': '1115',
#   'DayOfWeek': '2',
#   'Date': '2013-01-01',
#   'Sales': '0',
#   'Customers': '0',
#   'Open': '0',
#   'Promo': '0',
#   'StateHoliday': 'a',
#   'SchoolHoliday': '1'},
#  {'Store': '1114',
#   'DayOfWeek': '2',
#   'Date': '2013-01-01',
#   'Sales': '0',
#   'Customers': '0',
#   'Open': '0',
#   'Promo': '0',
#   'StateHoliday': 'a',
#   'SchoolHoliday': '1'}]

# %%
store_data[:2]
# Out:
# [{'Store': '1',
#   'StoreType': 'c',
#   'Assortment': 'a',
#   'CompetitionDistance': '1270',
#   'CompetitionOpenSinceMonth': '9',
#   'CompetitionOpenSinceYear': '2008',
#   'Promo2': '0',
#   'Promo2SinceWeek': '0',
#   'Promo2SinceYear': '0',
#   'PromoInterval': '0'},
#  {'Store': '2',
#   'StoreType': 'a',
#   'Assortment': 'a',
#   'CompetitionDistance': '570',
#   'CompetitionOpenSinceMonth': '11',
#   'CompetitionOpenSinceYear': '2007',
#   'Promo2': '1',
#   'Promo2SinceWeek': '13',
#   'Promo2SinceYear': '2010',
#   'PromoInterval': 'Jan,Apr,Jul,Oct'}]

# %%
def feature_list(record):
    dt = datetime.strptime(record['Date'], '%Y-%m-%d')
    store_index = int(record['Store'])
    year = dt.year
    month = dt.month
    day = dt.day
    day_of_week = int(record['DayOfWeek'])
    try:
        store_open = int(record['Open'])
    except:
        store_open = 1

    promo = int(record['Promo'])

    return [store_open,
            store_index,
            day_of_week,
            promo,
            year,
            month,
            day,
            state_data[store_index - 1]['State']
            ]

# %%
state_data[1000]
# Out:
# {'Store': '1001', 'State': 'TH'}

# %%
train_data_X = []
train_data_y = []

for record in train_data:
    if record['Sales'] != '0' and record['Open'] != '':
        fl = feature_list(record)
        train_data_X.append(fl)
        train_data_y.append(int(record['Sales']))
print("Number of train datapoints: ", len(train_data_y))

print(min(train_data_y), max(train_data_y))
# Out:
# Number of train datapoints:  844338
# 46 41551

# %%
train_data_X[0, :]
# Out:
# array([  0, 109,   1,   0,   0,   0,   0,   7])

# %%
full_X = train_data_X
full_X = np.array(full_X)

train_data_X = np.array(train_data_X)
les = []
for i in range(train_data_X.shape[1]):
    le = preprocessing.LabelEncoder()   # 将列特征进行 LabelEncoder
    le.fit(full_X[:, i])
    les.append(le)
    train_data_X[:, i] = le.transform(train_data_X[:, i])

with open('E:\\DL_datasets\\Rossmann\\les.pickle', 'wb') as f:
    pickle.dump(les, f, -1)

# %%
print(train_data_X.shape)
train_data_X[0, :]
# Out:
# (844338, 8)
# array([  0, 109,   1,   0,   0,   0,   0,   7])

# %%
train_data_X = train_data_X.astype(int)
train_data_y = np.array(train_data_y)

with open('E:\\DL_datasets\\Rossmann\\feature_train_data.pickle', 'wb') as f:
    pickle.dump((train_data_X, train_data_y), f, -1)
    print(train_data_X[0], train_data_y[0])
# Out:
# [  0 109   1   0   0   0   0   7] 5961

# %%
print(train_data_X.shape)
print(train_data_y.shape)
# Out:
# (844338, 8)
# (844338,)

# %% [markdown]
# ## train_test_model

# %%
import pickle
import numpy
numpy.random.seed(123)
from models import embed_features, NN_with_EntityEmbedding
from sklearn.preprocessing import OneHotEncoder
import sys
sys.setrecursionlimit(10000)  # 设置递归调用深度
# Out:
# Using TensorFlow backend.

# %%
train_ratio = 0.9
shuffle_data = False
one_hot_as_input = False
embeddings_as_input = False
save_embeddings = True
saved_embeddings_fname = "E:\\DL_datasets\\Rossmann\\embeddings.pickle"  # set save_embeddings to True to create this file

# %%
f = open('E:\\DL_datasets\\Rossmann\\feature_train_data.pickle', 'rb')
(X, y) = pickle.load(f)

# %%
num_records = len(X)
print('length of X:', num_records)
train_size = int(train_ratio * num_records)

if shuffle_data:
    print("Using shuffled data")
    sh = numpy.arange(X.shape[0])
    numpy.random.shuffle(sh)
    X = X[sh]
    y = y[sh]
# Out:
# length of X: 844338

# %%
if embeddings_as_input:
    print("Using learned embeddings as input")
    X = embed_features(X, saved_embeddings_fname)

# %%
if one_hot_as_input:
    print("Using one-hot encoding as input")
    enc = OneHotEncoder(sparse=False)
    enc.fit(X)
    X = enc.transform(X)

# %%
X_train = X[:train_size]
X_val = X[train_size:]
y_train = y[:train_size]
y_val = y[train_size:]

# %%
def sample(X, y, n):
    '''random samples'''
    num_row = X.shape[0]
    indices = numpy.random.randint(num_row, size=n)
    return X[indices, :], y[indices]

# %%
X_train, y_train = sample(X_train, y_train, 200000)  # Simulate data sparsity
print("Number of samples used for training: " + str(y_train.shape[0]))
# Out:
# Number of samples used for training: 200000

# %%
models = []

print("Fitting NN_with_EntityEmbedding...")
for i in range(5):
    models.append(NN_with_EntityEmbedding(X_train, y_train, X_val, y_val))
# Out:
# Fitting NN_with_EntityEmbedding...
# WARNING:tensorflow:From d:\python36\deeplearning\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From d:\python36\deeplearning\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 200000 samples, validate on 84434 samples
# Epoch 1/10
# 200000/200000 [==============================] - 31s 156us/step - loss: 0.0142 - val_loss: 0.0114
# Epoch 2/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0096 - val_loss: 0.0111
# Epoch 3/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0089 - val_loss: 0.0110
# Epoch 4/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0081 - val_loss: 0.0102
# Epoch 5/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0077 - val_loss: 0.0103
# Epoch 6/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0074 - val_loss: 0.0099
# Epoch 7/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0073 - val_loss: 0.0097
# Epoch 8/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0071 - val_loss: 0.0099
# Epoch 9/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0069 - val_loss: 0.0096
# Epoch 10/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0069 - val_loss: 0.0103
# Result on validation data:  0.105949035761244
# Train on 200000 samples, validate on 84434 samples
# Epoch 1/10
# 200000/200000 [==============================] - 17s 86us/step - loss: 0.0140 - val_loss: 0.0112
# Epoch 2/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0093 - val_loss: 0.0105
# Epoch 3/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0083 - val_loss: 0.0103
# Epoch 4/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0079 - val_loss: 0.0100
# Epoch 5/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0076 - val_loss: 0.0095
# Epoch 6/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0073 - val_loss: 0.0094
# Epoch 7/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 8/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0070 - val_loss: 0.0091
# Epoch 9/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0069 - val_loss: 0.0090
# Epoch 10/10
# 200000/200000 [==============================] - 16s 80us/step - loss: 0.0068 - val_loss: 0.0093
# Result on validation data:  0.09876747876182365
# Train on 200000 samples, validate on 84434 samples
# Epoch 1/10
# 200000/200000 [==============================] - 18s 89us/step - loss: 0.0141 - val_loss: 0.0116
# Epoch 2/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0093 - val_loss: 0.0105
# Epoch 3/10
# 200000/200000 [==============================] - 16s 81us/step - loss: 0.0084 - val_loss: 0.0102
# Epoch 4/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0079 - val_loss: 0.0101
# Epoch 5/10
# 200000/200000 [==============================] - 17s 86us/step - loss: 0.0076 - val_loss: 0.0103
# Epoch 6/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0074 - val_loss: 0.0110
# Epoch 7/10
# 200000/200000 [==============================] - 17s 84us/step - loss: 0.0072 - val_loss: 0.0099
# Epoch 8/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0071 - val_loss: 0.0094
# Epoch 9/10
# 200000/200000 [==============================] - 16s 81us/step - loss: 0.0070 - val_loss: 0.0097
# Epoch 10/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0068 - val_loss: 0.0098
# Result on validation data:  0.10234445525025833
# Train on 200000 samples, validate on 84434 samples
# Epoch 1/10
# 200000/200000 [==============================] - 17s 87us/step - loss: 0.0142 - val_loss: 0.0117
# Epoch 2/10
# 200000/200000 [==============================] - 17s 84us/step - loss: 0.0094 - val_loss: 0.0103
# Epoch 3/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0084 - val_loss: 0.0109
# Epoch 4/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0079 - val_loss: 0.0108
# Epoch 5/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0076 - val_loss: 0.0099
# Epoch 6/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0074 - val_loss: 0.0096
# Epoch 7/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0072 - val_loss: 0.0093
# Epoch 8/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0070 - val_loss: 0.0093
# Epoch 9/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0069 - val_loss: 0.0092
# Epoch 10/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0068 - val_loss: 0.0091
# Result on validation data:  0.09971202349590433
# Train on 200000 samples, validate on 84434 samples
# Epoch 1/10
# 200000/200000 [==============================] - 17s 87us/step - loss: 0.0144 - val_loss: 0.0118
# Epoch 2/10
# 200000/200000 [==============================] - 17s 84us/step - loss: 0.0094 - val_loss: 0.0110
# Epoch 3/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0084 - val_loss: 0.0099
# Epoch 4/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0079 - val_loss: 0.0099
# Epoch 5/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0076 - val_loss: 0.0099
# Epoch 6/10
# 200000/200000 [==============================] - 17s 83us/step - loss: 0.0074 - val_loss: 0.0097
# Epoch 7/10
# 200000/200000 [==============================] - 16s 82us/step - loss: 0.0072 - val_loss: 0.0100
# Epoch 8/10
# 200000/200000 [==============================] - 16s 81us/step - loss: 0.0071 - val_loss: 0.0097
# Epoch 9/10
# 200000/200000 [==============================] - 16s 81us/step - loss: 0.0069 - val_loss: 0.0096
# Epoch 10/10
# 200000/200000 [==============================] - 17s 85us/step - loss: 0.0068 - val_loss: 0.0096
# Result on validation data:  0.1023867486758752

# %%
if save_embeddings:
    model = models[0].model
    store_embedding = model.get_layer('store_embedding').get_weights()[0]
    dow_embedding = model.get_layer('dow_embedding').get_weights()[0]
    year_embedding = model.get_layer('year_embedding').get_weights()[0]
    month_embedding = model.get_layer('month_embedding').get_weights()[0]
    day_embedding = model.get_layer('day_embedding').get_weights()[0]
    german_states_embedding = model.get_layer('state_embedding').get_weights()[0]
    with open(saved_embeddings_fname, 'wb') as f:
        pickle.dump([store_embedding, dow_embedding, year_embedding,
                     month_embedding, day_embedding, german_states_embedding], f, -1)

# %%
def evaluate_models(models, X, y):
    assert(min(y) > 0)
    guessed_sales = numpy.array([model.guess(X) for model in models])
    mean_sales = guessed_sales.mean(axis=0)
    relative_err = numpy.absolute((y - mean_sales) / y)
    result = numpy.sum(relative_err) / len(y)
    return result

# %%
print("Evaluate combined models...")
print("Training error...")
r_train = evaluate_models(models, X_train, y_train)
print(r_train)

print("Validation error...")
r_val = evaluate_models(models, X_val, y_val)
print(r_val)
# Out:
# Evaluate combined models...
# Training error...
# 0.0637926522658677
# Validation error...
# 0.0930563890898449

# %%
dow_embedding.shape
# Out:
# (7, 6)

# %% [markdown]
# ## Plot Embeddings

# %%
import pickle
from sklearn import manifold
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
with open("E:\\DL_datasets\\Rossmann\\embeddings.pickle", 'rb') as f:
    [store_embedding, dow_embedding, year_embedding,
     month_embedding, day_embedding, german_states_embedding] = pickle.load(f)

# %%
# Load LabelEncoders
with open("E:\\DL_datasets\\Rossmann\\les.pickle", 'rb') as f:
    les = pickle.load(f)
le_store = les[1]
le_dow = les[2]
le_month = les[5]
le_day = les[6]
le_state = les[7]

# %%
list(le_state.classes_)
# Out:
# ['BE', 'BW', 'BY', 'HB,NI', 'HE', 'HH', 'NW', 'RP', 'SH', 'SN', 'ST', 'TH']

# %%
states_names = ['Berlin', 'Baden Wuerttemberg', 'Bayern', 'Niedersachsen/Bremen', 
                'Hessen', 'Hamburg', 'Nordrhein Westfalen', 'Rheinland Pfalz',
                'Schleswig Holstein', 'Sachsen', 'Sachsen Anhalt', 'Thueringen']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact')
Y = tsne.fit_transform(german_states_embedding)
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(states_names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-20, 8), textcoords = 'offset points')

# %%
list(le_dow.classes_)
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact')
Y = tsne.fit_transform(dow_embedding)
names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')

# %%
list(le_month.classes_)
# Out:
# ['1', '10', '11', '12', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact')
Y = tsne.fit_transform(month_embedding)
names = ['Jan', 'Oct', 'Nov', 'Dec', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact', learning_rate=500, verbose=2, early_exaggeration=1)
Y = tsne.fit_transform(store_embedding)
names = list(le_store.classes_)
plt.figure(figsize=(20,20))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]))
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1115
# [t-SNE] Computed conditional probabilities for sample 1115 / 1115
# [t-SNE] Mean sigma: 0.092937
# [t-SNE] Iteration 50: error = 1.3698889, gradient norm = 0.0013398 (50 iterations in 2.345s)
# [t-SNE] Iteration 100: error = 1.2920405, gradient norm = 0.0005796 (50 iterations in 2.326s)
# [t-SNE] Iteration 150: error = 1.2629076, gradient norm = 0.0003619 (50 iterations in 2.275s)
# [t-SNE] Iteration 200: error = 1.2481230, gradient norm = 0.0002380 (50 iterations in 2.412s)
# [t-SNE] Iteration 250: error = 1.2395229, gradient norm = 0.0001752 (50 iterations in 2.315s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 1.239523
# [t-SNE] Iteration 300: error = 1.2328230, gradient norm = 0.0001362 (50 iterations in 2.431s)
# [t-SNE] Iteration 350: error = 1.2257989, gradient norm = 0.0000769 (50 iterations in 2.424s)
# [t-SNE] Iteration 400: error = 1.2222258, gradient norm = 0.0000550 (50 iterations in 2.295s)
# [t-SNE] Iteration 450: error = 1.2201400, gradient norm = 0.0000637 (50 iterations in 2.386s)
# [t-SNE] Iteration 500: error = 1.2188448, gradient norm = 0.0000499 (50 iterations in 2.254s)
# [t-SNE] Iteration 550: error = 1.2179171, gradient norm = 0.0000286 (50 iterations in 2.254s)
# [t-SNE] Iteration 600: error = 1.2172648, gradient norm = 0.0000245 (50 iterations in 2.244s)
# [t-SNE] Iteration 650: error = 1.2167684, gradient norm = 0.0000225 (50 iterations in 2.397s)
# [t-SNE] Iteration 700: error = 1.2163770, gradient norm = 0.0000205 (50 iterations in 2.382s)
# [t-SNE] Iteration 750: error = 1.2160609, gradient norm = 0.0000177 (50 iterations in 2.284s)
# [t-SNE] Iteration 800: error = 1.2157970, gradient norm = 0.0000169 (50 iterations in 2.240s)
# [t-SNE] Iteration 850: error = 1.2155759, gradient norm = 0.0000153 (50 iterations in 2.257s)
# [t-SNE] Iteration 900: error = 1.2153837, gradient norm = 0.0000143 (50 iterations in 2.256s)
# [t-SNE] Iteration 950: error = 1.2152173, gradient norm = 0.0000134 (50 iterations in 2.276s)
# [t-SNE] Iteration 1000: error = 1.2150706, gradient norm = 0.0000127 (50 iterations in 2.256s)
# [t-SNE] KL divergence after 1000 iterations: 1.215071
